# %% [markdown]
# ## Logical Operator

# %% [markdown]
# ### NOT

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %% [markdown]
# ### AND

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
False and False
# Out:
# False

# %% [markdown]
# ### OR

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or True
# Out:
# True

# %%
False or False
# Out:
# False
