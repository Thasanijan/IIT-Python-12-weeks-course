# %% [markdown]
# # Python Notes

# %% [markdown]
# ## Week 01 homework

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("My future ambition is to become a Software Engineer")
# Out:
# My future ambition is to become a Software Engineer

# %%
print(9+6)
# Out:
# 15

# %%
print(35-20)
# Out:
# 15

# %%
print(5*3)
# Out:
# 15

# %%
print(45/3)
# Out:
# 15.0
