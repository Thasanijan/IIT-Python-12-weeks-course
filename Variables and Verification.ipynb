# %%
print('Hello World!')
# Out:
# Hello World!

# %%
print("Hi IIT")
# Out:
# Hi IIT

# %% [markdown]
# ## Variables

# %% [markdown]
# ### A name that stores a value — like a box that holds some data so you can use it later in your program.

# %% [markdown]
# ### Variable Declaration and verification

# %%
Name = 'Thasan'
Age = 23
print(Name)
print(Age)
# Out:
# Thasan
# 23

# %%
x = 10
y = "Sri Lanka"
z = 75.80
print(type(x))
print (type(y))
print (type(z))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
