# %% [markdown]
# # IIT Python Class

# %% [markdown]
# ## Week 01 homeworks

# %% [markdown]
# Very first command - print

# %%
print("Hello Sri Lanka")
# Out:
# Hello Sri Lanka

# %%
print('Hello Sri Lanka')
# Out:
# Hello Sri Lanka

# %%
print("My name is Thasanijan Soundararajan,")
print("I'm studying at IIT Campus,")
print('I love to do Python language as my favourite programming language,')
print("I am currently learning python language.")
# Out:
# My name is Thasanijan Soundararajan,
# I'm studying at IIT Campus,
# I love to do Python language as my favourite programming language,
# I am currently learning python language.
